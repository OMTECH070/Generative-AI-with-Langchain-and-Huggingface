# %% [markdown]
# ## Variable

# %%
a=100

# %%
age=18
height=6.1
name="Om"
is_student=True 

print(f"Name:{name}")
print(f"Age:{age}")
print(f"Height:{height}")
# Out:
# Name:Om
# Age:18
# Height:6.1

# %%
## Naming Convection
##Should be discriptive
##Must statr with letter or '_' and contain letter,number and underscore
##Case sensitive

## Valid Variable 
first_name="Om" 
last_name="Mahadik"

# %%
##Ivalid variable name 
#2age=18
#first-name="Om"
#@name="Mahadik"

##Case Sensitivity
name="Om"
Name="Mahadik"

name==Name
# Out:
# False

# %%
## Understanding Variable types
##Python is dynamically typed,type is determined at runtime 

age=18 #int
height=6.1 #float
name="OM"#str
is_student=True

# %%
##Type checking and conversion

age=float(age)
print(type(age))
print(age)
age=str(age)
print(type(age))
print(age)
# Out:
# <class 'str'>
# 18.0
# <class 'float'>
# 18.0
# <class 'str'>
# 18.0

# %%
height=5.11
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
## Dynamic Typing 
##python allows the type of a varibale to change as the program executes
var=10
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input 

age=int(input("Enter your age"))
print(age,type(age))
# Out:
# 18 <class 'int'>

# %%
## Simple calculator

num1=float(input("Enter the number 1:"))
num2=float(input("Enter the number 2:"))

add= num1+ num2
sub=num1 - num2
mul=num1*num2
div=num1/num2

print("Sum:",add)
print("Difference:",sub)
print("Product:",mul)
print("Quotienr:",div)
# Out:
# Sum: 15.0
# Difference: 5.0
# Product: 50.0
# Quotienr: 2.0
