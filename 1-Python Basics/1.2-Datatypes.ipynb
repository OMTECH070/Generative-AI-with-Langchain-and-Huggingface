# %% [markdown]
# ## Data Types

# %%
##Integer
age=18
type(age)
# Out:
# int

# %%
##Float
height=6.1
type(height)
# Out:
# float

# %%
name="Om"
print(name)
print(type(name))
# Out:
# Om
# <class 'str'>

# %%
is_true=True
type(is_true)
# Out:
# bool

# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
## Common Errors

result="Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 ## Common Errors
#       2
# ----> 3 result="Hello" + 5
#
# TypeError: can only concatenate str (not "int") to str
