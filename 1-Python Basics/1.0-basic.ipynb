# %% [markdown]
# ## Single Line Comment

# %%
## This is a singlr line comment

# %% [markdown]
# ## Case Sensitivity

# %%
name="Om"
Name="Mahadik"

print(name)
print(Name)
# Out:
# Om
# Mahadik

# %% [markdown]
# ## Indentation

# %%
age=18
if age <30:
    print(age)

print(age+1)
# Out:
# 18
# 19

# %%
## line continueation 
## for line continueation use backslash \

total=1+2+3+4+5+6\
+4+6+7
print(total)
# Out:
# 38

# %%
## multi statement on single line 
x=5;y=9;z=x+y
print(z)
# Out:
# 14

# %%
## variable assignment
age=18 ## age is an int
name="Om" ## name is an str

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type infrence
##during the run time you can clase the type of the variable
value=18
print(type(value))
value="Om"
print(type(value))
# Out:
# <class 'int'>
# <class 'str'>
