# %% [markdown]
# ## Operator

# %%
##Arithmetic Operator
a=10
b=5
add=a+b
sub=a-b
mul=a*b
div=a/b
floor_div=a//b
modulus=a%b
exp=a**b

print(add)
print(sub)
print(mul)
print(div)
print(floor_div)
print(modulus)
print(exp)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
##Comparison Operator

a=10
b=10

a==b
# Out:
# True

# %%
str1="Om"
str2="Om"

str1==str2
# Out:
# True

# %%
str1!=str2
# Out:
# False

# %%
str1="Om"
str2="Mahadik"

str1!=str2
# Out:
# True

# %%
x=100
y=55

x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
number1=45
number2=44

number1 >= number2
# Out:
# True

# %%
number1 <= number2
# Out:
# False

# %%
##Logical Operator
## And,Or ,Not

##AND only true when both are true
x=True;y=True

x and y
# Out:
# True

# %%
##OR 
x=False;y=True

x or y
# Out:
# True

# %%
##Not
x=True
not x
# Out:
# False
