# %% [markdown]
# ## Standard Library Overview

# %%
import array

arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random

print(random.randint(1,10))      #exclusive
print(random.randrange(1,10))    #inclusive
print(random.choice(["Apple","Banana","Cherry"]))
# Out:
# 2
# 7
# Apple

# %%
###File And Directory Access

import os
print(os.getcwd())
os.mkdir("test_dir")
# Out:
# e:\Generative AI with Langchain and Huggingface\Modules

# %%
##High Level operation on file and collection of files

import shutil as s

s.copyfile("source.txt","destination.txt")
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json as js

data={"Name":"Om","Age":19}

json_str=js.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=js.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"Name": "Om", "Age": 19}
# <class 'str'>
# {'Name': 'Om', 'Age': 19}
# <class 'dict'>

# %%
## CSV

import csv

with open("example.csv",mode='w',newline="") as file:
   writer= csv.writer(file)
   writer.writerow(["Name","Age"])
   writer.writerow(["Om","19"])
   writer.writerow(["Sai","12"])

with open("example.csv",mode="r") as file:
   reader=csv.reader(file)
   for row in reader:
      print(row)
# Out:
# ['Name', 'Age']
# ['Om', '19']
# ['Sai', '12']

# %%
##datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-24 22:45:35.585148
# 2026-06-23 22:45:35.585148

# %%
## time

import time
from datetime import datetime,timedelta

print(time.time())
time.sleep(5)


now=datetime.now()
print(now)
# Out:
# 1782321462.4329195
# 2026-06-24 22:47:47.433469

# %%
## Regular Expression

import re

pattern=r'\d+'
text="There are 123 apples"
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
