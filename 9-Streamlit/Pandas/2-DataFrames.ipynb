# %%
import numpy as np
import pandas as pd
# Out:
# Exception ignored in PyObject_HasAttr(); consider using PyObject_HasAttrWithError(), PyObject_GetOptionalAttr() or PyObject_GetAttr():
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 491, in _call_with_frames_removed
# AttributeError: partially initialized module 'pandas' from 'e:\Generative AI with Langchain and Huggingface\venv\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %% [markdown]
# ## Creating DataFrame

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 28, 35, 27],
    "City": ["New York", "London", "Mumbai", "Sydney", "Toronto"],
    "Salary": [55000, 62000, 48000, 75000, 59000]
}

df1 = pd.DataFrame(data)

# %%
df1
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   55000
# 1      Bob   30    London   62000
# 2  Charlie   28    Mumbai   48000
# 3    David   35    Sydney   75000
# 4     Emma   27   Toronto   59000

# %%
data_list=[
    ["Alice", 25, "New York", 55000],
    ["Bob", 30, "London", 62000],
    ["Charlie", 28, "Mumbai", 48000],
    ["David", 35, "Sydney", 75000],
    ["Emma", 27, "Toronto", 59000]
]

df2=pd.DataFrame(data_list)

# %%
df2
# Out:
#          0   1         2      3
# 0    Alice  25  New York  55000
# 1      Bob  30    London  62000
# 2  Charlie  28    Mumbai  48000
# 3    David  35    Sydney  75000
# 4     Emma  27   Toronto  59000

# %%
df3=pd.DataFrame(data_list,columns=["Name","Age","City","Salary"])
df3
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   55000
# 1      Bob   30    London   62000
# 2  Charlie   28    Mumbai   48000
# 3    David   35    Sydney   75000
# 4     Emma   27   Toronto   59000

# %% [markdown]
# ## Selection and Indexing of Columns

# %%
df3
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   55000
# 1      Bob   30    London   62000
# 2  Charlie   28    Mumbai   48000
# 3    David   35    Sydney   75000
# 4     Emma   27   Toronto   59000

# %%
df3["Name"]
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4       Emma
# Name: Name, dtype: str

# %%
df3[["Name", "Salary"]]
# Out:
#       Name  Salary
# 0    Alice   55000
# 1      Bob   62000
# 2  Charlie   48000
# 3    David   75000
# 4     Emma   59000

# %% [markdown]
# ## Creating a new Column

# %%
df3["Gender"]=["Female", "Male", "Male", "Male", "Female"]
df3
# Out:
#       Name  Age      City  Salary  Gender
# 0    Alice   25  New York   55000  Female
# 1      Bob   30    London   62000    Male
# 2  Charlie   28    Mumbai   48000    Male
# 3    David   35    Sydney   75000    Male
# 4     Emma   27   Toronto   59000  Female

# %% [markdown]
# ## Removing Columns

# %%
df3
# Out:
#       Name  Age      City  Salary  Gender
# 0    Alice   25  New York   55000  Female
# 1      Bob   30    London   62000    Male
# 2  Charlie   28    Mumbai   48000    Male
# 3    David   35    Sydney   75000    Male
# 4     Emma   27   Toronto   59000  Female

# %%
df3.drop("Gender", axis=1, inplace=True)
df3
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   55000
# 1      Bob   30    London   62000
# 2  Charlie   28    Mumbai   48000
# 3    David   35    Sydney   75000
# 4     Emma   27   Toronto   59000

# %%
df3.drop(["City", "Salary"], axis=1)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28
# 3    David   35
# 4     Emma   27

# %%
df3.drop(0,axis=0)
# Out:
#       Name  Age     City  Salary
# 1      Bob   30   London   62000
# 2  Charlie   28   Mumbai   48000
# 3    David   35   Sydney   75000
# 4     Emma   27  Toronto   59000

# %% [markdown]
# ## Selecting Rows

# %%
df3
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   55000
# 1      Bob   30    London   62000
# 2  Charlie   28    Mumbai   48000
# 3    David   35    Sydney   75000
# 4     Emma   27   Toronto   59000

# %%
df3.loc[0]
# Out:
# Name         Alice
# Age             25
# City      New York
# Salary       55000
# Name: 0, dtype: object

# %%
df3.loc[[0,1]]
# Out:
#     Name  Age      City  Salary
# 0  Alice   25  New York   55000
# 1    Bob   30    London   62000

# %% [markdown]
# ## Selecting Subsets of Rows and Columns

# %%
df3
# Out:
#       Name  Age      City  Salary
# 0    Alice   25  New York   55000
# 1      Bob   30    London   62000
# 2  Charlie   28    Mumbai   48000
# 3    David   35    Sydney   75000
# 4     Emma   27   Toronto   59000

# %%
df3.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   55000
# 1    London   62000

# %%
df3.loc[[3,4]][["Name","Age"]]
# Out:
#     Name  Age
# 3  David   35
# 4   Emma   27

# %% [markdown]
# ## Conditional Selection

# %%
## I only want to see those ppl whose age is above 30

# %%
df3[df3["Age"]>= 30]
# Out:
#     Name  Age    City  Salary
# 1    Bob   30  London   62000
# 3  David   35  Sydney   75000

# %%
#I only want to see those ppl whose age is above 30  and salary is above 65000

# %%
df3[(df3["Age"]>= 30) & (df3["Salary"]>= 65000)]
# Out:
#     Name  Age    City  Salary
# 3  David   35  Sydney   75000
