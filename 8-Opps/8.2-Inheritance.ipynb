# %% [markdown]
# ## Inheritance In Python

# %%
## Imheritance
## Parent class
class Car:
    def __init__ (self,windows,doors,enginetype):
        self.windows=windows
        self.doores=doors
        self.enginetype=enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

car1=Car(8,5,"V12")

print(car1.windows)
car1.drive()
# Out:
# 8
# The person will drive the V12 car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving=is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports selfdriving : {self.is_selfdriving}")

# %%
t1=Tesla(4,5,"Electric",True)
t1.selfdriving()
t1.drive()
# Out:
# Tesla supports selfdriving : True
# The person will drive the Electric car

# %%
# Base class 1
class Animals:

    def __init__(self, name, no_legs):
        self.name = name
        self.legs = no_legs

    def Legs(self):
        print(f"{self.name} has {self.legs} legs")


# Base class 2
class Pet:

    def __init__(self, owner):
        self.owner = owner


# Derived class
class Dog(Animals, Pet):

    def __init__(self, name, no_legs, owner):
        Animals.__init__(self, name, no_legs)
        Pet.__init__(self, owner)

    def speak(self):
        return f"{self.name} says Woof!"


dog = Dog("Sai", 4, "Om")

print(dog.speak())
print(dog.owner)
print(dog.legs)
dog.Legs()
# Out:
# Sai says Woof!
# Om
# 4
# Sai has 4 legs
