# %%
# !pip install gensim
# Out:
# ^C
# ...
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/23.3 MB ? eta -:--:--
# ...
